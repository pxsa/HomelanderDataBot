# %%
import pandas as pd

# %%
df = pd.read_csv("submissions.csv")
df.head()
# Out:
#    id    user_id username  score  max_score         submitted_at  \
# 0   1  515083284    Parsa    100        100  2026-07-06 13:08:47
#
#    stress_level  attempt_number  file_size_bytes  error_count  is_perfect
# 0             2               1             2044            0           1
